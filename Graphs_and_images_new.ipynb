# %% [markdown]
# <a href="https://colab.research.google.com/github/hanrach/marked-beetle-analysis/blob/main/Graphs_and_images_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import shutil
import json
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from PIL import Image
from matplotlib import axes
import matplotlib.pyplot as plt
from collections import Counter
from keras.preprocessing.image import ImageDataGenerator

import cv2
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Loading filenames which we will use for both original and threshcropped datasets

# %%
filenames = os.listdir("/content/drive/MyDrive/MarkedBeetleImageAnalysis")

train_images=[]
for filename in filenames:
    if 'light' not in filename:
      if filename.startswith('Papered') or filename.startswith('NoPapered'):
        train_images.append(filename)
categories = []
for filename in train_images:
    if filename.startswith('Papered') or filename.startswith('Pink') or filename.startswith('Trap'):
        categories.append('marked')
    if filename.startswith('NoPapered'):
        categories.append('unmarked')
df = pd.DataFrame({
    'filename': train_images,
    'category': categories
})
dfmark=df[df['category']=='marked']
dfunmark=df[df['category']=='unmarked']

# %% [markdown]
# Excluding "light" images

# %%
light_images=[]
for filename in filenames:
  if 'light' in filename:
    light_images.append(filename)

len(light_images)
light_images[0]
# Out:
# 'PaperedControl21v_light.tif'

# %%
def visualize_batch(image_ids):
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", image_ids[0]))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title("(a) Included image", fontsize=10)
    plt.axis("off")
    
    plt.subplot(1, 2, 2 )
    image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", image_ids[1]))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.imshow(image)
    plt.title("(b) Excluded image", fontsize=10)
    plt.axis("off")
    
    #plt.suptitle('Original images and their Threshcropped counterparts')
    plt.savefig("/content/drive/MyDrive/figures/included_excluded_beetleimages.eps", dpi=600)
    plt.show()

# %%
image_ids=[train_images[6], light_images[0]]
image_ids
# Out:
# ['PaperedControl24d.tif', 'PaperedControl21v_light.tif']

# %%
visualize_batch(image_ids)

# %% [markdown]
#  **Section 1: Dataset statistics**

# %% [markdown]
# 1. Distribution of categories in the dataset

# %%
df['category'].value_counts()
# Out:
# marked      479
# unmarked    278
# Name: category, dtype: int64

# %%
ax = sns.countplot(y='category', data=df)
ax.set(title='Marked vs Unmarked in the dataset')
ax.text(440,0, "479", color='white')
ax.text(240,1, "278", color='white')
# Out:
# Text(240, 1, '278')

# %% [markdown]
# 2. Training and validation set stats

# %%
train_df1, validate_df1 = train_test_split(dfmark, test_size = 0.2, random_state = 42, stratify = dfmark['category'])
train_df1 = train_df1.reset_index(drop=True)
validate_df1 = validate_df1.reset_index(drop=True)
train_df2, validate_df2 = train_test_split(dfunmark, test_size = 0.2, random_state = 42, stratify = dfunmark['category'])
train_df2 = train_df2.reset_index(drop=True)
validate_df2 = validate_df2.reset_index(drop=True)
train_df=train_df1.append(train_df2)
validate_df=validate_df1.append(validate_df2)

# %%
train_df['category'].value_counts()
# Out:
# marked      383
# unmarked    222
# Name: category, dtype: int64

# %%
ax = sns.countplot(y='category', data=train_df)
ax.set(title='Marked vs Unmarked in the training dataset')
ax.text(360,0, "383", color='white')
ax.text(190,1, "222", color='white')
# Out:
# Text(190, 1, '222')

# %%
validate_df['category'].value_counts()
# Out:
# marked      96
# unmarked    56
# Name: category, dtype: int64

# %%
ax = sns.countplot(y='category', data=validate_df)
ax.set(title='Marked vs Unmarked in the validation dataset')
ax.text(90,0, "96", color='white')
ax.text(50,1, "56", color='white')
# Out:
# Text(50, 1, '56')

# %% [markdown]
# Summary of dataset statistics

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,4), sharey=True)

#subplot 1
plt.subplot(1,3,1)
ax1= sns.countplot(y='category', data=df)
ax1.set_title('(a) Entire dataset', fontsize = 10)
ax1.text(440,0, "479", color='white')
ax1.text(240,1, "278", color='white')
#subplot 2

plt.subplot(1,3,2)
ax2= sns.countplot(y='category', data=train_df)
ax2.set_title('(b) Training dataset', fontsize=10)
ax2.text(350,0, "383", color='white')
ax2.text(190,1, "222", color='white')
plt.ylabel(" ")


#subplot 3
plt.subplot(1,3,3)
ax3 = sns.countplot(y='category', data=validate_df)
ax3.set_title('(c) Validation dataset', fontsize=10)
ax3.text(90,0, "96", color='white')
ax3.text(50,1, "56", color='white')
plt.ylabel(" ")

plt.savefig("/content/drive/MyDrive/figures/datastats.eps", dpi=600)
#plt.suptitle('Marked vs Unmarked in datasets')
plt.show()

# %% [markdown]
# **Section 2: Batch visualization**

# %%
def visualize_batch(image_ids, labels):
    plt.figure(figsize=(8, 6))
    for ind, (image_id, label) in enumerate(zip(image_ids, labels)):
        plt.subplot(2, 2, ind+1 )
        image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", image_id))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        plt.imshow(image)
        plt.title(f"{label}", fontsize=10)
        plt.axis("off")
    for ind, (image_id, label) in enumerate(zip(image_ids, labels)):
        plt.subplot(2, 2, ind+3 )
        image = cv2.imread(os.path.join("/content/drive/MyDrive/GrayscaleThresholdBeetleImages", image_id))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        plt.imshow(image)
        #plt.title(f"{label}", fontsize=12)
        plt.axis("off")
    
    #plt.suptitle('Original images and their Threshcropped counterparts')
    plt.savefig("/content/drive/MyDrive/figures/org_thresh_beetleimages.eps", dpi=600)
    plt.show()

# %%
tmp_df = df.sample(2)
tmp_df
# Out:
#                       filename  category
# 372      NoPaperedGreen40v.tif  unmarked
# 212  PaperedTransparent49d.tif    marked

# %%
image_ids = tmp_df["filename"].values
labels = tmp_df["category"].values

visualize_batch(image_ids, labels)

# %% [markdown]
# **Secton 2.5 Overall metrics comparisons - with batch size 32 and image size 600**

# %%
test_models=['Human Classifier', 'EfficientNetB0 Org', 'EfficientNetB0 Thresh', 'EfficientNetB3 Org', 'EfficientNetB3 Thresh', 'EfficientNetB7 Org', 'EfficientNetB7 Thresh', 'Resnet50 Org', 'Resnet50 Thresh']
Val_accuracy=[76.4, 63.15, 75.65,63.81,79.60, 67.10, 76.31, 74.34, 84.86]
F1_score=['n/a', 77.41, 82.94, 77.73, 84.42, 77.06, 82.17, 74.83, 87.83]
Time=['n/a', 50, 41, 398, 74, 628, 909, 72, 103]
overall_df=pd.DataFrame({'Model':test_models, 'Validation Accuracy': Val_accuracy, 'F1 score': F1_score, 'Time(minutes)': Time})
overall_df
# Out:
#                    Model  Validation Accuracy F1 score Time(minutes)
# 0       Human Classifier                76.40      n/a           n/a
# 1     EfficientNetB0 Org                63.15    77.41            50
# 2  EfficientNetB0 Thresh                75.65    82.94            41
# 3     EfficientNetB3 Org                63.81    77.73           398
# 4  EfficientNetB3 Thresh                79.60    84.42            74
# 5     EfficientNetB7 Org                67.10    77.06           628
# 6  EfficientNetB7 Thresh                76.31    82.17           909
# 7           Resnet50 Org                74.34    74.83            72
# 8        Resnet50 Thresh                84.86    87.83           103

# %% [markdown]
# **Section 3: Resnet finetuning - threshcropped**

# %% [markdown]
# 1. Varying image size

# %%
threshcrop_vary_image=pd.read_csv('/content/drive/MyDrive/fine_tuning/threshcropmetrics.txt')
threshcrop_vary_image
# Out:
#    IMAGE SIZE   VAL ACCURACY   PRECISION    RECALL   F1_SCORE
# 0         500       0.881579    0.890000  0.927083   0.908163
# 1         400       0.822368    0.834951  0.895833   0.864322
# 2         300       0.842105    0.882979  0.864583   0.873684
# 3         200       0.815789    0.809091  0.927083   0.864078
# 4         100       0.697368    0.812500  0.677083   0.738636
# 5         600       0.835526    0.890110  0.843750   0.866310

# %%
threshcrop_vary_image.dtypes
# Out:
# IMAGE SIZE         int64
#  VAL ACCURACY    float64
#  PRECISION       float64
#  RECALL          float64
#  F1_SCORE        float64
# dtype: object

# %%
columns=threshcrop_vary_image.columns

# %%
columns[0]
# Out:
# 'IMAGE SIZE'

# %%
threshcrop_vary_image=threshcrop_vary_image.sort_values(by=[columns[0]])

# %%
ax_im=plt.gca()
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[1], style='o-',ax=ax_im)
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[2], style='o-', ax=ax_im)
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[3], style='o-', ax=ax_im)
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[4], style='o-', ax=ax_im)
plt.title('Threshcropped images - comparing metrics')
plt.show()

# %% [markdown]
# Choosing image size on the basis of best F1 score

# %%
threshcrop_vary_image.loc[threshcrop_vary_image[columns[4]].idxmax()]
# Out:
# IMAGE SIZE       500.000000
#  VAL ACCURACY      0.881579
#  PRECISION         0.890000
#  RECALL            0.927083
#  F1_SCORE          0.908163
# Name: 0, dtype: float64

# %%
ax_im=plt.gca()
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[1], style='o-', ax=ax_im)
threshcrop_vary_image.plot(kind='line', x=columns[0], y=columns[4], style='o-', ax=ax_im)
plt.axvline(x=500, color='gray', linestyle='--')

plt.title('Threshcropped images - optimizing image size')
plt.show()

# %% [markdown]
# 2. Comparing batch size at image size = 500

# %%
threshcrop_vary_batchsize=pd.read_csv('/content/drive/MyDrive/fine_tuning/threshcropmetrics500.txt')
threshcrop_vary_batchsize=threshcrop_vary_batchsize.sort_values(by=[columns[0]])
#threshcrop_vary_image=threshcrop_vary_image.sort_values(by=[columns[0]])

# %%
columns=threshcrop_vary_batchsize.columns
ax_im=plt.gca()
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[1], style='o-', ax=ax_im)
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[2], style='o-', ax=ax_im)
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[3], style='o-', ax=ax_im)
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[4], style='o-', ax=ax_im)
plt.title('Threshcropped images - comparing metrics at imagesize 500')
plt.show()

# %% [markdown]
# Choosing batchsize based on the best F1 score

# %%
threshcrop_vary_batchsize.loc[threshcrop_vary_batchsize[columns[4]].idxmax()]
# Out:
# BATCH SIZE    30.000000
#  ACCURACY      0.842105
#  PRECISION     0.833333
#  RECALL        0.937500
#  F1 SCORE      0.882353
# Name: 1, dtype: float64

# %%
ax_b=plt.gca()
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[1], style='o-', ax=ax_b)
threshcrop_vary_batchsize.plot(kind='line', x=columns[0], y=columns[4], style='o-', ax=ax_b)
plt.axvline(x=30, color='gray', linestyle='--')

plt.title('Threshcropped images - optimizing batch size at image size 500')
plt.show()

# %% [markdown]
# Summarizing the threshcrop optimization process

# %%
columns_im=threshcrop_vary_image.columns
columns_b=threshcrop_vary_batchsize.columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

#subplot 1
#threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[1], style='o-',ax=axes[0,0])
#threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[2], style='o-', ax=axes[0,0])
#threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[3], style='o-', ax=axes[0,0])
#threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[4], style='o-', ax=axes[0,0])
#axes[0,0].set_title('Varying image size')

#subplot 2
threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[1], style='o-', ax=axes[0])
threshcrop_vary_image.plot(kind='line', x=columns_im[0], y=columns_im[4], style='ro-', ax=axes[0])
axes[0].axvline(x=500, color='gray', linestyle='--')
axes[0].set_title('(a) Optimizing image size')

#subplot 3
#threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[1], style='o-', ax=axes[1,0])
#threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[2], style='o-', ax=axes[1,0])
#threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[3], style='o-', ax=axes[1,0])
#threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[4], style='o-', ax=axes[1,0])
#axes[1,0].set_title('Varying batch size at image size 500')

#subplot 4
threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[1], style='o-', ax=axes[1])
threshcrop_vary_batchsize.plot(kind='line', x=columns_b[0], y=columns_b[4], style='ro-', ax=axes[1])
axes[1].axvline(x=30, color='gray', linestyle='--')
axes[1].set_title('(b) Optimizing batch size at image size 500')

#plt.suptitle('Fine tuning image and batch sizes for threshcropped images')
plt.savefig("/content/drive/MyDrive/figures/thesh_optimise.eps", dpi=600)

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# **Section 4: Resnet finetuning - original**

# %%
tvi=pd.read_csv('/content/drive/MyDrive/fine_tuning/metrics.txt')
tvi=tvi.sort_values(by=[tvi.columns[0]])
tvi
# Out:
#    Image size   Val_accuracy   Precision    Recall   F1 score
# 4         100       0.796053    0.901235  0.760417    0.824859
# 3         200       0.802632    0.823529  0.875000    0.848485
# 2         300       0.973684    0.969388  0.989583    0.979381
# 1         400       0.967105    0.969072  0.979167    0.974093
# 0         500       0.907895    0.901961  0.958333    0.929293

# %%
ax_im=plt.gca()
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[1], style='o-',ax=ax_im)
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[2], style='o-', ax=ax_im)
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[3], style='o-', ax=ax_im)
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[4], style='ro-', ax=ax_im)
ax_im.set_title('Varying image size')
plt.show()

# %% [markdown]
# Choosing best image size based on F1 score

# %%
tvi.loc[tvi[tvi.columns[4]].idxmax()]
# Out:
# Image size       300.000000
#  Val_accuracy      0.973684
#  Precision         0.969388
#  Recall            0.989583
#  F1 score          0.979381
# Name: 2, dtype: float64

# %%
ax_im=plt.gca()
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[1], style='o-',ax=ax_im)
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[4], style='ro-', ax=ax_im)
ax_im.axvline(x=300, color='gray', linestyle='--')
ax_im.set_title('Optimizing image size wrt F1 score')
plt.show()

# %% [markdown]
# Varying batchsize based on the best image size

# %%
tvb=pd.read_csv('/content/drive/MyDrive/fine_tuning/metrics_300.txt')
#tvb=tvb.drop(labels=[0,1], axis=0)
#tvb=tvb.sort_values(by=tvb.columns[0])
tvb
# Out:
#    BATCH SIZE   VAL ACCURACY   PRECISION    RECALL   F1 SCORE
# 0          10       0.947368    0.958333  0.958333   0.958333
# 1          20       0.815789    1.000000  0.708333   0.829268
# 2          30       0.868421    0.839286  0.979167   0.903846
# 3          32       0.947368    0.940000  0.979167   0.959184
# 4          35       0.901316    0.987952  0.854167   0.916201
# 5          40       0.947368    0.968085  0.947917   0.957895
# 6          50       0.881579    0.854545  0.979167   0.912621

# %%
ax_im=plt.gca()
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[1], style='o-',ax=ax_im)
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[2], style='o-', ax=ax_im)
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[3], style='o-', ax=ax_im)
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[4], style='ro-', ax=ax_im)
ax_im.set_title('Original images - varying batchsize at image size 300')
plt.show()

# %% [markdown]
# Optimizing batchsize with respect to F1 score

# %%
tvb.loc[tvb[tvb.columns[4]].idxmax()]
# Out:
# BATCH SIZE       32.000000
#  VAL ACCURACY     0.947368
#  PRECISION        0.940000
#  RECALL           0.979167
#  F1 SCORE         0.959184
# Name: 3, dtype: float64

# %%
ax_im=plt.gca()
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[1], style='o-',ax=ax_im)
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[4], style='ro-', ax=ax_im)
ax_im.axvline(x=32,color='gray', linestyle='--')
ax_im.set_title('Optimizing batchsize wrt F1 score at image size 300')
plt.show()

# %% [markdown]
# Summary of fine tuning parameters for original images

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

#subplot 1
#tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[1], style='o-',ax=axes[0,0])
#tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[2], style='o-', ax=axes[0,0])
#tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[3], style='o-', ax=axes[0,0])
#tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[4], style='ro-', ax=axes[0,0])
#axes[0,0].set_title('Varying image size')

#subplot 2
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[1], style='o-',ax=axes[0])
tvi.plot(kind='line', x=tvi.columns[0], y=tvi.columns[4], style='ro-', ax=axes[0])
axes[0].axvline(x=300, color='gray', linestyle='--')
axes[0].set_title('(a) Optimizing image size')

#subplot 3
#tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[1], style='o-',ax=axes[1,0])
#tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[2], style='o-', ax=axes[1,0])
#tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[3], style='o-', ax=axes[1,0])
#tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[4], style='ro-', ax=axes[1,0])
#axes[1,0].set_title('Varying batchsize at image size 300')

#subplot 4
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[1], style='o-',ax=axes[1])
tvb.plot(kind='line', x=tvb.columns[0], y=tvb.columns[4], style='ro-', ax=axes[1])
axes[1].axvline(x=32,color='gray', linestyle='--')
axes[1].set_title('(b) Optimizing batchsize image size 300')

#plt.suptitle('Fine tuning image and batch sizes for original images')
plt.savefig("/content/drive/MyDrive/figures/org_optimise.eps", dpi=600)

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# **Section 5: Best model with original and threshcropped**

# %% [markdown]
# 1. Original

# %%
IMG_SIZE = 300
size = (IMG_SIZE,IMG_SIZE)
n_CLASS = 2
BATCH_SIZE = 32

test_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    )
test_generator1 = test_gen.flow_from_dataframe(
    validate_df, 
    "/content/drive/MyDrive/MarkedBeetleImageAnalysis/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=size,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 152 validated image filenames.

# %%
import keras
model_o = keras.models.load_model('/content/drive/MyDrive/fine_tuning/resnet50_original_300.h5')

# %%
to_samples=validate_df.shape[0]
predict = model_o.predict(test_generator1, steps=np.ceil(to_samples/BATCH_SIZE))

# %%
validate_df['or_prediction'] = np.argmax(predict, axis=1)
validate_df["or_prediction"] = validate_df["or_prediction"].replace({1: 'unmarked', 0: 'marked'}) 
validate_df
# Out:
#                      filename  category or_prediction
# 0   PaperedTransparent22v.tif    marked        marked
# 1   PaperedTransparent88d.tif    marked        marked
# 2   PaperedTransparent97d.tif    marked        marked
# 3         PaperedMixed24d.tif    marked        marked
# 4   PaperedTransparent42d.tif    marked        marked
# ..                        ...       ...           ...
# 51      NoPaperedGreen76v.tif  unmarked      unmarked
# 52      NoPaperedGreen85d.tif  unmarked      unmarked
# 53      NoPaperedGreen16d.tif  unmarked      unmarked
# 54       NoPaperedMixed7v.tif  unmarked      unmarked
# 55      NoPaperedMixed11d.tif  unmarked      unmarked
#
# [152 rows x 3 columns]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_true=list(validate_df['category'])
y_pred=list(validate_df['or_prediction'])
cm_or=confusion_matrix(y_true, y_pred, labels=["marked", "unmarked"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm_or, display_labels=["marked", "unmarked"])
disp.plot(values_format="d")

# %%
tp=cm_or[0,0]
tn=cm_or[1,1]
fp = cm_or[1,0]
fn = cm_or[0,1]
precision = float(tp/(tp+fp))
recall = tp/(tp+fn)
f1_score = 2*precision*recall/(precision+recall)
accuracy = (tp+tn)/(tp+tn+fp+fn)
print("The Validation Accuracy is", accuracy)
print("The precision is ", precision)
print("The recall is ", recall)
print("The F1 score is ", f1_score)
# Out:
# The Validation Accuracy is 0.9736842105263158
# The precision is  0.9693877551020408
# The recall is  0.9895833333333334
# The F1 score is  0.9793814432989691

# %%
f1_score_or=f1_score
val_acc_or=accuracy

# %% [markdown]
# 2. Theshcropped

# %%
IMG_SIZE = 500
size = (IMG_SIZE,IMG_SIZE)
n_CLASS = 2
BATCH_SIZE = 32
to_samples=validate_df.shape[0]

test_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    )
test_generator1 = test_gen.flow_from_dataframe(
    validate_df, 
    "/content/drive/MyDrive/GrayscaleThresholdBeetleImages/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=size,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 152 validated image filenames.

# %%
import keras
model_t = keras.models.load_model('/content/drive/MyDrive/fine_tuning/Resnet50_threshcropped_500.h5')

# %%
predict2 = model_t.predict(test_generator1, steps=np.ceil(to_samples/BATCH_SIZE))

# %%
validate_df['th_prediction'] = np.argmax(predict2, axis=1)
validate_df["th_prediction"] = validate_df["th_prediction"].replace({1: 'unmarked', 0: 'marked'}) 
validate_df
# Out:
#                      filename  category or_prediction th_prediction
# 0   PaperedTransparent22v.tif    marked        marked        marked
# 1   PaperedTransparent88d.tif    marked        marked        marked
# 2   PaperedTransparent97d.tif    marked        marked        marked
# 3         PaperedMixed24d.tif    marked        marked        marked
# 4   PaperedTransparent42d.tif    marked        marked        marked
# ..                        ...       ...           ...           ...
# 51      NoPaperedGreen76v.tif  unmarked      unmarked      unmarked
# 52      NoPaperedGreen85d.tif  unmarked      unmarked      unmarked
# 53      NoPaperedGreen16d.tif  unmarked      unmarked      unmarked
# 54       NoPaperedMixed7v.tif  unmarked      unmarked        marked
# 55      NoPaperedMixed11d.tif  unmarked      unmarked        marked
#
# [152 rows x 4 columns]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_true_t=list(validate_df['category'])
y_pred_t=list(validate_df['th_prediction'])
cm_t=confusion_matrix(y_true_t, y_pred_t, labels=["marked", "unmarked"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm_t, display_labels=["marked", "unmarked"])
disp.plot(values_format="d")

# %%
tp=cm_t[0,0]
tn=cm_t[1,1]
fp = cm_t[1,0]
fn = cm_t[0,1]
precision = float(tp/(tp+fp))
recall = tp/(tp+fn)
f1_score = 2*precision*recall/(precision+recall)
accuracy = (tp+tn)/(tp+tn+fp+fn)
print("The Validation Accuracy is", accuracy)
print("The precision is ", precision)
print("The recall is ", recall)
print("The F1 score is ", f1_score)
f1_score_t=f1_score
val_acc_t=accuracy
# Out:
# The Validation Accuracy is 0.8947368421052632
# The precision is  0.8846153846153846
# The recall is  0.9583333333333334
# The F1 score is  0.9199999999999999

# %% [markdown]
# Summaring best models from original and threshcropped images

# %%
models=pd.DataFrame({'Model':['Original', 'Threshcropped'], 'Validation accuracy':[val_acc_or, val_acc_t], 'F1 score': [f1_score_or, f1_score_t]})

# %%
ax=models.plot.bar(x='Model', figsize=(10,7), rot=0)

# %% [markdown]
# **Conclusion: Use the trained model "model_o" for predictions.**

# %% [markdown]
# Generating dataset of filenames with Trap beetles

# %%
filenames = os.listdir("/content/drive/MyDrive/MarkedBeetleImageAnalysis")
trap_images=[]
for filename in filenames:
  if filename.startswith('Trap'):
        trap_images.append(filename)
print(f"Number of Train images: {len(trap_images)}") #filename.startswith('Pink')
# Out:
# Number of Train images: 77

# %%
categories=[]
for filename in trap_images:
  categories.append('unknown')
len(categories)
# Out:
# 77

# %%
trap_df = pd.DataFrame({
    'filename': trap_images,
    'category': categories
})
trap_df
# Out:
#                       filename category
# 0     Trap48182019632pmB1v.tif  unknown
# 1     Trap48182019632pmB1d.tif  unknown
# 2     Trap48182019632pmB2v.tif  unknown
# 3     Trap48182019632pmB2d.tif  unknown
# 4    Trap681520191020amB2v.tif  unknown
# ..                         ...      ...
# 72  Trap79072019529pmpredv.tif  unknown
# 73  Trap79072019529pmpredd.tif  unknown
# 74  Trap39072019530pmparav.tif  unknown
# 75  Trap39072019530pmparad.tif  unknown
# 76  Trap59072019533pmparal.tif  unknown
#
# [77 rows x 2 columns]

# %% [markdown]
# Applying our chosen parameters and preprocessing to this dataset

# %%
import keras
model_o = keras.models.load_model('/content/drive/MyDrive/fine_tuning/resnet50_original_300.h5')

# %%
IMG_SIZE = 300
size = (IMG_SIZE,IMG_SIZE)
n_CLASS = 2
BATCH_SIZE = 32

test_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    )
test_generator1 = test_gen.flow_from_dataframe(
    trap_df, 
    "/content/drive/MyDrive/MarkedBeetleImageAnalysis/", 

    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=size,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 77 validated image filenames.

# %%
to_samples=trap_df.shape[0]
predict = model_o.predict(test_generator1, steps=np.ceil(to_samples/BATCH_SIZE))

# %%
predict
# Out:
# array([[5.6070706e-04, 9.9943930e-01],
#        [8.6560583e-01, 1.3439409e-01],
#        [4.9151620e-04, 9.9950850e-01],
#        [9.8054296e-01, 1.9456973e-02],
#        [1.5941652e-05, 9.9998403e-01],
#        [2.2740474e-04, 9.9977261e-01],
#        [6.7456378e-05, 9.9993253e-01],
#        [3.2018581e-01, 6.7981422e-01],
#        [1.1185325e-03, 9.9888152e-01],
#        [9.9701333e-01, 2.9866260e-03],
#        [1.1718946e-04, 9.9988282e-01],
#        [5.1622323e-05, 9.9994838e-01],
#        [3.8003458e-05, 9.9996197e-01],
#        [5.0090225e-03, 9.9499100e-01],
#        [1.4673392e-03, 9.9853265e-01],
#        [1.1912136e-03, 9.9880874e-01],
#        [5.3932779e-03, 9.9460679e-01],
#        [1.6662518e-02, 9.8333746e-01],
#        [1.5023056e-03, 9.9849772e-01],
#        [1.5515427e-01, 8.4484577e-01],
#        [3.0531219e-01, 6.9468778e-01],
#        [7.4400747e-01, 2.5599256e-01],
#        [3.4563865e-03, 9.9654359e-01],
#        [2.3664681e-02, 9.7633535e-01],
#        [1.6314289e-06, 9.9999833e-01],
#        [3.6860807e-03, 9.9631399e-01],
#        [1.9705438e-03, 9.9802941e-01],
#        [2.6027233e-06, 9.9999738e-01],
#        [1.7344899e-02, 9.8265505e-01],
#        [4.1640598e-01, 5.8359402e-01],
#        [2.7435720e-03, 9.9725646e-01],
#        [9.1494006e-01, 8.5059963e-02],
#        [9.1633838e-01, 8.3661616e-02],
#        [5.0910777e-01, 4.9089223e-01],
#        [6.2664290e-04, 9.9937338e-01],
#        [9.5222217e-01, 4.7777854e-02],
#        [2.3096509e-03, 9.9769032e-01],
#        [4.1940291e-03, 9.9580598e-01],
#        [7.9561663e-01, 2.0438333e-01],
#        [2.1977849e-01, 7.8022152e-01],
#        [1.0272871e-04, 9.9989724e-01],
#        [8.6627698e-01, 1.3372296e-01],
#        [8.7866187e-03, 9.9121338e-01],
#        [1.4692324e-03, 9.9853075e-01],
#        [7.0258699e-05, 9.9992979e-01],
#        [2.1141467e-03, 9.9788588e-01],
#        [1.3548221e-01, 8.6451781e-01],
#        [1.6490799e-01, 8.3509201e-01],
#        [1.1554127e-04, 9.9988449e-01],
#        [6.8556177e-03, 9.9314439e-01],
#        [5.5060326e-04, 9.9944943e-01],
#        [6.1356486e-04, 9.9938643e-01],
#        [3.6280963e-04, 9.9963713e-01],
#        [5.8633923e-03, 9.9413657e-01],
#        [3.1992965e-06, 9.9999678e-01],
#        [5.5020180e-05, 9.9994493e-01],
#        [6.2119294e-02, 9.3788075e-01],
#        [2.2978912e-01, 7.7021092e-01],
#        [3.4526311e-04, 9.9965477e-01],
#        [5.0237862e-04, 9.9949765e-01],
#        [8.4423050e-03, 9.9155772e-01],
#        [9.2757700e-06, 9.9999070e-01],
#        [5.2416247e-01, 4.7583747e-01],
#        [1.3107100e-01, 8.6892897e-01],
#        [8.8194979e-04, 9.9911803e-01],
#        [1.3262181e-03, 9.9867380e-01],
#        [2.7801460e-02, 9.7219849e-01],
#        [8.3841521e-01, 1.6158485e-01],
#        [2.6877223e-02, 9.7312272e-01],
#        [4.9236267e-05, 9.9995077e-01],
#        [3.4378475e-04, 9.9965620e-01],
#        [1.0062156e-04, 9.9989939e-01],
#        [1.6583358e-04, 9.9983418e-01],
#        [1.9599898e-02, 9.8040009e-01],
#        [1.8457675e-03, 9.9815422e-01],
#        [6.2632107e-04, 9.9937373e-01],
#        [9.5312625e-01, 4.6873797e-02]], dtype=float32)

# %%
trap_df['prediction'] = np.argmax(predict, axis=1)
trap_df['prediction prob'] = np.amax(predict, axis=1)
trap_df["prediction"] = trap_df["prediction"].replace({1: 'unmarked', 0: 'marked'}) 
trap_df
# Out:
#                       filename category prediction  prediction prob
# 0     Trap48182019632pmB1v.tif  unknown   unmarked         0.999439
# 1     Trap48182019632pmB1d.tif  unknown     marked         0.865606
# 2     Trap48182019632pmB2v.tif  unknown   unmarked         0.999509
# 3     Trap48182019632pmB2d.tif  unknown     marked         0.980543
# 4    Trap681520191020amB2v.tif  unknown   unmarked         0.999984
# ..                         ...      ...        ...              ...
# 72  Trap79072019529pmpredv.tif  unknown   unmarked         0.999834
# 73  Trap79072019529pmpredd.tif  unknown   unmarked         0.980400
# 74  Trap39072019530pmparav.tif  unknown   unmarked         0.998154
# 75  Trap39072019530pmparad.tif  unknown   unmarked         0.999374
# 76  Trap59072019533pmparal.tif  unknown     marked         0.953126
#
# [77 rows x 4 columns]

# %%
trap_df['prediction'].value_counts()
# Out:
# unmarked    64
# marked      13
# Name: prediction, dtype: int64

# %% [markdown]
# Visualise the batch and probablities

# %%
def visualize_pred(image_ids, labels, predictions):
  plt.figure(figsize=(12,8))
  for ind, (image_id, label, prediction) in enumerate(zip(image_ids, labels, predictions)):
    plt.subplot(2, 2, ind+1 )
    image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", image_id))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(f"{label}" + " probablity " + f" {prediction}", fontsize=10)
    plt.axis("off")
    
  #plt.suptitle('Prediction on trap images')
  plt.savefig("/content/drive/MyDrive/figures/beetleimageswithprobsnew.eps", dpi=600)
  plt.show()

# %%
tmp_df = trap_df.sample(4)

image_ids = tmp_df["filename"].values
labels = tmp_df["prediction"].values
predictions = tmp_df["prediction prob"].values

# %%
labels
# Out:
# array(['marked', 'unmarked', 'unmarked', 'unmarked'], dtype=object)

# %%
labels[0]='(a) marked'
labels[1]='(b) unmarked'
labels[2]='(c) unmarked'
labels[3]='(d) unmarked'

# %%
labels
# Out:
# array(['(a) marked', '(b) unmarked', '(c) unmarked', '(d) unmarked'],
#       dtype=object)

# %%
visualize_pred(image_ids, labels, predictions)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-527e25e1d0b0> in <module>()
# ----> 1 visualize_pred(image_ids, labels, predictions)
#
# <ipython-input-81-90bf974bd902> in visualize_pred(image_ids, labels, predictions)
#      10
#      11   #plt.suptitle('Prediction on trap images')
# ---> 12   plt.savefig("/content/drive/MyDrive/figures/beetleimageswithprobsnew.eps", dpi=600)
#      13   plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_ps.py in print_eps(self, outfile, *args, **kwargs)
#     829
#     830     def print_eps(self, outfile, *args, **kwargs):
# --> 831         return self._print_ps(outfile, 'eps', *args, **kwargs)
#     832
#     833     def _print_ps(self, outfile, format, *args,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_ps.py in _print_ps(self, outfile, format, papertype, dpi, facecolor, edgecolor, orientation, *args, **kwargs)
#     849                    self._print_figure)
#     850         printer(outfile, format, dpi, facecolor, edgecolor,
# --> 851                 orientation, papertype, **kwargs)
#     852
#     853     @cbook._delete_parameter("3.2", "dryrun")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_ps.py in _print_figure(self, outfile, format, dpi, facecolor, edgecolor, orientation, papertype, metadata, dryrun, bbox_inches_restore, **kwargs)
#     936             bbox_inches_restore=bbox_inches_restore)
#     937
# --> 938         self.figure.draw(renderer)
#     939
#     940         if dryrun:  # return immediately if dryrun (tightbbox=True)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     158                 image_group.append(a)
#     159             else:
# --> 160                 flush_images()
#     161                 a.draw(renderer)
#     162         flush_images()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in flush_images()
#     143         def flush_images():
#     144             if len(image_group) == 1:
# --> 145                 image_group[0].draw(renderer)
#     146             elif len(image_group) > 1:
#     147                 data, l, b = composite_images(image_group, renderer, mag)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     626                 renderer, renderer.get_image_magnification())
#     627             if im is not None:
# --> 628                 renderer.draw_image(gc, l, b, im)
#     629         gc.restore()
#     630         self.stale = False
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_ps.py in draw_image(self, gc, x, y, im, transform)
#     346         # data.tobytes().hex() has no spaces, so can be linewrapped by relying
#     347         # on textwrap.fill breaking long words.
# --> 348         hexlines = textwrap.fill(data.tobytes().hex(), 128)
#     349
#     350         if transform is None:
#
# /usr/lib/python3.7/textwrap.py in fill(text, width, **kwargs)
#     389     """
#     390     w = TextWrapper(width=width, **kwargs)
# --> 391     return w.fill(text)
#     392
#     393 def shorten(text, width, **kwargs):
#
# /usr/lib/python3.7/textwrap.py in fill(self, text)
#     361         containing the entire wrapped paragraph.
#     362         """
# --> 363         return "\n".join(self.wrap(text))
#     364
#     365
#
# /usr/lib/python3.7/textwrap.py in wrap(self, text)
#     352         if self.fix_sentence_endings:
#     353             self._fix_sentence_endings(chunks)
# --> 354         return self._wrap_chunks(chunks)
#     355
#     356     def fill(self, text):
#
# /usr/lib/python3.7/textwrap.py in _wrap_chunks(self, chunks)
#     295             # fit on *any* line (not just this one).
#     296             if chunks and len(chunks[-1]) > width:
# --> 297                 self._handle_long_word(chunks, cur_line, cur_len, width)
#     298                 cur_len = sum(map(len, cur_line))
#     299
#
# /usr/lib/python3.7/textwrap.py in _handle_long_word(self, reversed_chunks, cur_line, cur_len, width)
#     217         if self.break_long_words:
#     218             cur_line.append(reversed_chunks[-1][:space_left])
# --> 219             reversed_chunks[-1] = reversed_chunks[-1][space_left:]
#     220
#     221         # Otherwise, we have to preserve the long word intact.  Only add
#
# KeyboardInterrupt:
