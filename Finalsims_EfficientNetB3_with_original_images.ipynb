# %% [markdown]
# <a href="https://colab.research.google.com/github/hanrach/marked-beetle-analysis/blob/main/Finalsims_EfficientNetB3_with_original_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import shutil
import json
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from PIL import Image
import matplotlib.pyplot as plt
from collections import Counter
from keras.preprocessing.image import ImageDataGenerator

import cv2
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filenames = os.listdir("/content/drive/MyDrive/MarkedBeetleImageAnalysis")
filenames[:4]
# Out:
# ['PaperedControl21v_light.tif',
#  'PaperedControl21d.tif',
#  'PaperedControl21d_light.tif',
#  'PaperedControl22v.tif']

# %%
train_images=[]
for filename in filenames:
    if 'light' not in filename:
      if filename.startswith('Papered') or filename.startswith('NoPapered'):
        train_images.append(filename)
print(f"Number of Train images: {len(train_images)}") #filename.startswith('Pink')
# Out:
# Number of Train images: 757

# %%
test_images=[]
for filename in filenames:
    if filename.startswith('Trap'):
        test_images.append(filename)
print(f"Number of Test images: {len(test_images)}")
# Out:
# Number of Test images: 77

# %%
categories = []
for filename in train_images:
    if filename.startswith('Papered') or filename.startswith('Pink') or filename.startswith('Trap'):
        categories.append('marked')
    if filename.startswith('NoPapered'):
        categories.append('unmarked')
len(categories)
# Out:
# 757

# %%
df = pd.DataFrame({
    'filename': train_images,
    'category': categories
})
df
# Out:
#                   filename category
# 0    PaperedControl21d.tif   marked
# 1    PaperedControl22v.tif   marked
# 2    PaperedControl22d.tif   marked
# 3    PaperedControl23v.tif   marked
# 4    PaperedControl23d.tif   marked
# ..                     ...      ...
# 752  PaperedControl19v.tif   marked
# 753  PaperedControl19d.tif   marked
# 754  PaperedControl20v.tif   marked
# 755  PaperedControl20d.tif   marked
# 756  PaperedControl21v.tif   marked
#
# [757 rows x 2 columns]

# %%
df['category'].value_counts()
# Out:
# marked      479
# unmarked    278
# Name: category, dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.countplot(y="category", data=df);

# %%
image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", filenames[0]))
image.shape
# Out:
# (1944, 2592, 3)

# %%
def visualize_batch(image_ids, labels):
    plt.figure(figsize=(16, 12))
    for ind, (image_id, label) in enumerate(zip(image_ids, labels)):
        plt.subplot(3, 3, ind+1 )
        image = cv2.imread(os.path.join("/content/drive/MyDrive/MarkedBeetleImageAnalysis", image_id))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        plt.imshow(image)
        plt.title(f"{label}", fontsize=12)
        plt.axis("off")
    
    plt.show()

# %%
tmp_df = df.sample(9)
tmp_df
# Out:
#                        filename  category
# 359       NoPaperedGreen14d.tif  unmarked
# 150   PaperedTransparent17v.tif    marked
# 298   PaperedTransparent91v.tif    marked
# 510       NoPaperedMixed13d.tif  unmarked
# 673         PaperedMixed44d.tif    marked
# 542       NoPaperedMixed29v.tif  unmarked
# 485       NoPaperedGreen85d.tif  unmarked
# 321  PaperedTransparent102d.tif    marked
# 511       NoPaperedMixed13v.tif  unmarked

# %%
image_ids = tmp_df["filename"].values
labels = tmp_df["category"].values

visualize_batch(image_ids, labels)

# %%
#df["category"] = df["category"].replace({0: 'NotMarked', 1: 'Marked'})

# %%
train_df, validate_df = train_test_split(df, test_size = 0.20, random_state = 42, stratify = df['category'])
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
IMG_SIZE = 600
size = (IMG_SIZE,IMG_SIZE)
n_CLASS = 5
BATCH_SIZE = 50

# %%
datagen_train = ImageDataGenerator(
                    preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    rotation_range = 40,
                    brightness_range = [0.3,0.9],
                    channel_shift_range = 50.0,
                    width_shift_range = 0.2,
                    height_shift_range = 0.2,
                    shear_range = 0.2,
                    zoom_range = 0.2,
                    horizontal_flip = True,
                    vertical_flip = True,
                    fill_mode = 'nearest')

# %%
datagen_val = ImageDataGenerator(
                    preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    )

# %%
train_set = datagen_train.flow_from_dataframe(train_df,
                             directory = "/content/drive/MyDrive/MarkedBeetleImageAnalysis",
                             seed=42,
                             x_col = 'filename',
                             y_col = 'category',
                             target_size = size,
                             #color_mode="rgb",
                             class_mode = 'categorical',
                             interpolation = 'nearest',
                             shuffle = True,
                             batch_size = BATCH_SIZE)
# Out:
# Found 605 validated image filenames belonging to 2 classes.

# %%
validate_set = datagen_val.flow_from_dataframe(validate_df,
                             directory = "/content/drive/MyDrive/MarkedBeetleImageAnalysis",
                             seed=42,
                             x_col = 'filename',
                             y_col = 'category',
                             target_size = size,
                             #color_mode="rgb",
                             class_mode = 'categorical',
                             interpolation = 'nearest',
                             shuffle = True,
                             batch_size = BATCH_SIZE)
# Out:
# Found 152 validated image filenames belonging to 2 classes.

# %%
from tensorflow.keras import layers
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )

# %%
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D, Flatten, Dense, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import  Adam, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import EfficientNetB3
def create_model():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    model = EfficientNetB3(include_top=False, input_tensor=inputs, weights="imagenet")
    #model = EfficientNetB7(input_shape = (IMG_SIZE, IMG_SIZE, 3), include_top = False,
                            # weights = 'imagenet',
                             #drop_connect_rate=0.6)
    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.Flatten()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Dense(256, activation = 'relu', bias_regularizer=tf.keras.regularizers.L1L2(l1=0.01, l2=0.001))(x)

    top_dropout_rate = 0.5
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(2, activation="sigmoid", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    return model

model = create_model()
model.summary()
# Out:
# Model: "EfficientNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 600, 600, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 600, 600, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 600, 600, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 601, 601, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 300, 300, 40  1080        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 300, 300, 40  160         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 300, 300, 40  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 300, 300, 40  360        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 300, 300, 40  160        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 300, 300, 40  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 300, 300, 40  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 300, 300, 24  960         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 300, 300, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 300, 300, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 300, 300, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 300, 300, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 300, 300, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 300, 300, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 300, 300, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 300, 300, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 300, 300, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 300, 300, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 300, 300, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 300, 300, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 301, 301, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 150, 150, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 150, 150, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 150, 150, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 150, 150, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 150, 150, 32  4608        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 150, 150, 19  6144        ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 150, 150, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 150, 150, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_dwconv (DepthwiseConv2  (None, 150, 150, 19  1728       ['block2b_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2b_bn (BatchNormalization  (None, 150, 150, 19  768        ['block2b_dwconv[0][0]']
#  )                              2)
#
#  block2b_activation (Activation  (None, 150, 150, 19  0          ['block2b_bn[0][0]']
#  )                              2)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 150, 150, 19  0           ['block2b_activation[0][0]',
#                                 2)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 150, 150, 32  6144        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 150, 150, 32  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 150, 150, 32  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 150, 150, 19  6144        ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 150, 150, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 150, 150, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_dwconv (DepthwiseConv2  (None, 150, 150, 19  1728       ['block2c_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2c_bn (BatchNormalization  (None, 150, 150, 19  768        ['block2c_dwconv[0][0]']
#  )                              2)
#
#  block2c_activation (Activation  (None, 150, 150, 19  0          ['block2c_bn[0][0]']
#  )                              2)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 150, 150, 19  0           ['block2c_activation[0][0]',
#                                 2)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 150, 150, 32  6144        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 150, 150, 32  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 150, 150, 32  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 150, 150, 19  6144        ['block2c_add[0][0]']
#                                 2)
#
#  block3a_expand_bn (BatchNormal  (None, 150, 150, 19  768        ['block3a_expand_conv[0][0]']
#  ization)                       2)
#
#  block3a_expand_activation (Act  (None, 150, 150, 19  0          ['block3a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 153, 153, 19  0          ['block3a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 75, 75, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 75, 75, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 75, 75, 48)   9216        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 75, 75, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 75, 75, 288)  13824       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 75, 75, 288)  1152       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 75, 75, 288)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 75, 75, 288)  7200       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 75, 75, 288)  1152       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 75, 75, 288)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 75, 75, 288)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 75, 75, 48)   13824       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 75, 75, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 75, 75, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 75, 75, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 75, 75, 288)  13824       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 75, 75, 288)  1152       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 75, 75, 288)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 75, 75, 288)  7200       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 75, 75, 288)  1152       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 75, 75, 288)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 75, 75, 288)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 75, 75, 48)   13824       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 75, 75, 48)  192         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 75, 75, 48)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 75, 75, 48)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 75, 75, 288)  13824       ['block3c_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 75, 75, 288)  1152       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 75, 75, 288)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 77, 77, 288)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 38, 38, 288)  2592       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 38, 38, 288)  1152       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 38, 38, 288)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 38, 38, 288)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 38, 38, 96)   27648       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 38, 38, 576)  55296       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 38, 38, 576)  2304       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 38, 38, 576)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 38, 38, 576)  5184       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 38, 38, 576)  2304       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 38, 38, 576)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 38, 38, 576)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 38, 38, 96)   55296       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 38, 38, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 38, 38, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 38, 38, 576)  55296       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 38, 38, 576)  2304       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 38, 38, 576)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 38, 38, 576)  5184       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 38, 38, 576)  2304       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 38, 38, 576)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 38, 38, 576)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 38, 38, 96)   55296       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 38, 38, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 38, 38, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 38, 38, 576)  55296       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 38, 38, 576)  2304       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 38, 38, 576)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv (DepthwiseConv2  (None, 38, 38, 576)  5184       ['block4d_expand_activation[0][0]
#  D)                                                              ']
#
#  block4d_bn (BatchNormalization  (None, 38, 38, 576)  2304       ['block4d_dwconv[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 38, 38, 576)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 38, 38, 576)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 38, 38, 96)   55296       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 38, 38, 96)   0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 38, 38, 96)   0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 38, 38, 576)  55296       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 38, 38, 576)  2304       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 38, 38, 576)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv (DepthwiseConv2  (None, 38, 38, 576)  5184       ['block4e_expand_activation[0][0]
#  D)                                                              ']
# ...
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 19, 19, 1392  0           ['block6e_activation[0][0]',
#                                 )                                 'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 19, 19, 232)  322944      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 19, 19, 232)  928        ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 19, 19, 232)  0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 19, 19, 232)  0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 19, 19, 1392  322944      ['block6e_add[0][0]']
#                                 )
#
#  block6f_expand_bn (BatchNormal  (None, 19, 19, 1392  5568       ['block6f_expand_conv[0][0]']
#  ization)                       )
#
#  block6f_expand_activation (Act  (None, 19, 19, 1392  0          ['block6f_expand_bn[0][0]']
#  ivation)                       )
#
#  block6f_dwconv (DepthwiseConv2  (None, 19, 19, 1392  34800      ['block6f_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6f_bn (BatchNormalization  (None, 19, 19, 1392  5568       ['block6f_dwconv[0][0]']
#  )                              )
#
#  block6f_activation (Activation  (None, 19, 19, 1392  0          ['block6f_bn[0][0]']
#  )                              )
#
#  block6f_se_squeeze (GlobalAver  (None, 1392)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 19, 19, 1392  0           ['block6f_activation[0][0]',
#                                 )                                 'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 19, 19, 232)  322944      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 19, 19, 232)  928        ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 19, 19, 232)  0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 19, 19, 232)  0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 19, 19, 1392  322944      ['block6f_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 19, 19, 1392  5568       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 19, 19, 1392  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 19, 19, 1392  12528      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 19, 19, 1392  5568       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 19, 19, 1392  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1392)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 19, 19, 1392  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 19, 19, 384)  534528      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 19, 19, 384)  1536       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 19, 19, 2304  884736      ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 19, 19, 2304  9216       ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 19, 19, 2304  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 19, 19, 2304  20736      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 19, 19, 2304  9216       ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 19, 19, 2304  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2304)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 19, 19, 2304  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 19, 19, 384)  884736      ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 19, 19, 384)  1536       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 19, 19, 384)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 19, 19, 384)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 19, 19, 1536  589824      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 19, 19, 1536  6144        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 19, 19, 1536  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['top_activation[0][0]']
#  2D)
#
#  flatten (Flatten)              (None, 1536)         0           ['avg_pool[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1536)        6144        ['flatten[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 256)          393472      ['batch_normalization[0][0]']
#
#  top_dropout (Dropout)          (None, 256)          0           ['dense[0][0]']
#
#  pred (Dense)                   (None, 2)            514         ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 11,183,665
# Trainable params: 397,058
# Non-trainable params: 10,786,607
# __________________________________________________________________________________________________

# %%
EPOCHS = 50
STEP_SIZE_TRAIN = train_set.n//train_set.batch_size
STEP_SIZE_VALID = validate_set.n//validate_set.batch_size

# %%
def Model_fit():
    
    model = create_model()
    '''Compiling the model'''
    #unfreeze_model(model)
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits = False,
                                                   label_smoothing=0.0001,
                                                   name='categorical_crossentropy' )
    
    model.compile(optimizer = Adam(learning_rate = 1e-3),
                        loss = loss, #'categorical_crossentropy'
                        metrics = ['accuracy']) #'acc'
    
        # Stop training when the val_loss has stopped decreasing for 3 epochs.
    stop = EarlyStopping(monitor='val_loss', mode='min', patience=3,
                       restore_best_weights=True, verbose=1)
    
    # Save the model with the minimum validation loss
    checkpoint_cb = ModelCheckpoint("B0_original_images_model.h5",
                                    save_best_only=True,
                                    monitor = 'val_loss',
                                    mode='min')
    
    # reduce learning rate
    reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                                  factor = 0.2,
                                  patience = 2,
                                  min_lr = 1e-6,
                                  mode = 'min',
                                  verbose = 1)
    history = model.fit(train_set,
                             validation_data = validate_set,
                             epochs= EPOCHS,
                             batch_size = BATCH_SIZE,
                             #class_weight = d_class_weights,
                             steps_per_epoch = STEP_SIZE_TRAIN,
                             validation_steps = STEP_SIZE_VALID,
                             callbacks=[stop, checkpoint_cb, reduce_lr])
    model.save('/content/drive/MyDrive/finalsims_B0_original.h5')  
    return history

# %%
# %%time
results = Model_fit()
# Out:
# Epoch 1/50
# 12/12 [==============================] - ETA: 0s - loss: 0.9821 - accuracy: 0.6378
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 12/12 [==============================] - 909s 73s/step - loss: 0.9821 - accuracy: 0.6378 - val_loss: 0.5443 - val_accuracy: 0.7267 - lr: 0.0010
# Epoch 2/50
# 12/12 [==============================] - 705s 58s/step - loss: 0.8249 - accuracy: 0.7063 - val_loss: 0.5149 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 3/50
# 12/12 [==============================] - 706s 58s/step - loss: 0.8169 - accuracy: 0.7225 - val_loss: 0.4733 - val_accuracy: 0.8400 - lr: 0.0010
# Epoch 4/50
# 12/12 [==============================] - 717s 59s/step - loss: 0.7919 - accuracy: 0.7279 - val_loss: 0.4463 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 5/50
# 12/12 [==============================] - 744s 61s/step - loss: 0.7411 - accuracy: 0.7300 - val_loss: 0.4250 - val_accuracy: 0.8467 - lr: 0.0010
# Epoch 6/50
# 12/12 [==============================] - 726s 60s/step - loss: 0.6324 - accuracy: 0.7586 - val_loss: 0.4254 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 7/50
# 12/12 [==============================] - ETA: 0s - loss: 0.7003 - accuracy: 0.7622
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 12/12 [==============================] - 736s 60s/step - loss: 0.7003 - accuracy: 0.7622 - val_loss: 0.4393 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 8/50
# 12/12 [==============================] - 740s 61s/step - loss: 0.5717 - accuracy: 0.7892 - val_loss: 0.3915 - val_accuracy: 0.8533 - lr: 2.0000e-04
# Epoch 9/50
# 12/12 [==============================] - 725s 60s/step - loss: 0.5175 - accuracy: 0.8090 - val_loss: 0.3748 - val_accuracy: 0.8533 - lr: 2.0000e-04
# Epoch 10/50
# 12/12 [==============================] - 735s 60s/step - loss: 0.5855 - accuracy: 0.7820 - val_loss: 0.3594 - val_accuracy: 0.8667 - lr: 2.0000e-04
# Epoch 11/50
# 12/12 [==============================] - 763s 63s/step - loss: 0.4863 - accuracy: 0.8100 - val_loss: 0.3590 - val_accuracy: 0.8467 - lr: 2.0000e-04
# Epoch 12/50
# 12/12 [==============================] - 744s 61s/step - loss: 0.5494 - accuracy: 0.7910 - val_loss: 0.4264 - val_accuracy: 0.7333 - lr: 2.0000e-04
# Epoch 13/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5939 - accuracy: 0.8018
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 12/12 [==============================] - 743s 61s/step - loss: 0.5939 - accuracy: 0.8018 - val_loss: 0.3652 - val_accuracy: 0.8267 - lr: 2.0000e-04
# Epoch 14/50
# 12/12 [==============================] - 746s 67s/step - loss: 0.5587 - accuracy: 0.8144 - val_loss: 0.3560 - val_accuracy: 0.8267 - lr: 4.0000e-05
# Epoch 15/50
# 12/12 [==============================] - 749s 61s/step - loss: 0.5571 - accuracy: 0.7784 - val_loss: 0.3407 - val_accuracy: 0.8333 - lr: 4.0000e-05
# Epoch 16/50
# 12/12 [==============================] - 753s 61s/step - loss: 0.5527 - accuracy: 0.7784 - val_loss: 0.3414 - val_accuracy: 0.8267 - lr: 4.0000e-05
# Epoch 17/50
# 12/12 [==============================] - ETA: 0s - loss: 0.4613 - accuracy: 0.7946
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 12/12 [==============================] - 754s 62s/step - loss: 0.4613 - accuracy: 0.7946 - val_loss: 0.3449 - val_accuracy: 0.8267 - lr: 4.0000e-05
# Epoch 18/50
# 12/12 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.7658 Restoring model weights from the end of the best epoch: 15.
# 12/12 [==============================] - 755s 68s/step - loss: 0.5299 - accuracy: 0.7658 - val_loss: 0.3455 - val_accuracy: 0.8267 - lr: 8.0000e-06
# Epoch 00018: early stopping
# CPU times: user 5h 57min 8s, sys: 41min 46s, total: 6h 38min 55s
# Wall time: 3h 50min 41s

# %%
print('Train_Cat-Acc: ', max(results.history['accuracy']))
print('Val_Cat-Acc: ', max(results.history['val_accuracy']))
# Out:
# Train_Cat-Acc:  0.8144144415855408
# Val_Cat-Acc:  0.8666666746139526

# %%
print('Train_Cat-Loss: ', min(results.history['loss']))
print('Val_Cat-Loss: ', min(results.history['val_loss']))
# Out:
# Train_Cat-Loss:  0.4613346755504608
# Val_Cat-Loss:  0.34071221947669983

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" EfficientNetB3 METRICS VISUALIZATION ", fontsize=20)

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy', fontsize=15)
    ax1.set_xlabel('Epochs', fontsize=15)
    ax1.set_ylabel('Accuracy', fontsize=15)
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss', fontsize=15)
    ax2.set_xlabel('Epochs', fontsize=15)
    ax2.set_ylabel('Loss', fontsize=15)
    ax2.legend(['training', 'validation'])
    plt.show()
    

Train_Val_Plot(results.history['accuracy'],results.history['val_accuracy'],
               results.history['loss'],results.history['val_loss'])

# %%
final_model = keras.models.load_model('/content/drive/MyDrive/finalsims_B0_original.h5')

# %%
tmp_df1=df.sample(10)
tmp_df1
# Out:
#                       filename  category
# 545      NoPaperedMixed30d.tif  unmarked
# 118   PaperedTransparent1v.tif    marked
# 751      PaperedControl18d.tif    marked
# 257  PaperedTransparent70d.tif    marked
# 692       NoPaperedMixed4d.tif  unmarked
# 620        PaperedMixed18v.tif    marked
# 299  PaperedTransparent91d.tif    marked
# 734       NoPaperedGreen9d.tif  unmarked
# 75       PaperedControl58d.tif    marked
# 559      NoPaperedMixed37d.tif  unmarked

# %%
nb_samples = tmp_df1.shape[0]
nb_samples
# Out:
# 10

# %%
test_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    rotation_range = 40,
                    brightness_range = [0.3,0.9],
                    channel_shift_range = 50.0,
                    width_shift_range = 0.2,
                    height_shift_range = 0.2,
                    shear_range = 0.2,
                    zoom_range = 0.2,
                    horizontal_flip = True,
                    vertical_flip = True,
                    fill_mode = 'nearest')
test_generator = test_gen.flow_from_dataframe(
    tmp_df1, 
    "/content/drive/MyDrive/MarkedBeetleImageAnalysis/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=size,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 10 validated image filenames.

# %%
predict = final_model.predict(test_generator, steps=np.ceil(nb_samples/BATCH_SIZE))

# %%
tmp_df1['prediction'] = np.argmax(predict, axis=-1)
tmp_df1["prediction"] = tmp_df1["prediction"].replace({1: 'unmarked', 0: 'marked'}) 
tmp_df1
# Out:
#                       filename  category prediction
# 545      NoPaperedMixed30d.tif  unmarked     marked
# 118   PaperedTransparent1v.tif    marked     marked
# 751      PaperedControl18d.tif    marked     marked
# 257  PaperedTransparent70d.tif    marked     marked
# 692       NoPaperedMixed4d.tif  unmarked     marked
# 620        PaperedMixed18v.tif    marked     marked
# 299  PaperedTransparent91d.tif    marked     marked
# 734       NoPaperedGreen9d.tif  unmarked     marked
# 75       PaperedControl58d.tif    marked     marked
# 559      NoPaperedMixed37d.tif  unmarked     marked

# %%
to_samples = df.shape[0]

# %%
test_gen = ImageDataGenerator(preprocessing_function = tf.keras.applications.efficientnet.preprocess_input,
                    rotation_range = 40,
                    brightness_range = [0.3,0.9],
                    channel_shift_range = 50.0,
                    width_shift_range = 0.2,
                    height_shift_range = 0.2,
                    shear_range = 0.2,
                    zoom_range = 0.2,
                    horizontal_flip = True,
                    vertical_flip = True,
                    fill_mode = 'nearest')
test_generator1 = test_gen.flow_from_dataframe(
    validate_df, 
    "/content/drive/MyDrive/MarkedBeetleImageAnalysis/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=size,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 152 validated image filenames.

# %%
predict = final_model.predict(test_generator1, steps=np.ceil(152/BATCH_SIZE))

# %%
predict
# Out:
# array([[0.70744133, 0.22179759],
#        [0.53974336, 0.14526302],
#        [0.5299001 , 0.3033629 ],
#        [0.45479602, 0.17187434],
#        [0.5844461 , 0.07146388],
#        [0.45445737, 0.18010804],
#        [0.61992574, 0.08114138],
#        [0.6225848 , 0.14028913],
#        [0.41749942, 0.1953915 ],
#        [0.37265402, 0.15737641],
#        [0.2531339 , 0.22387776],
#        [0.36044246, 0.2488758 ],
#        [0.4486559 , 0.19547665],
#        [0.42044023, 0.11969173],
#        [0.51097125, 0.11439517],
#        [0.38508505, 0.16636932],
#        [0.6283257 , 0.1165871 ],
#        [0.59548897, 0.15801466],
#        [0.5522692 , 0.14004582],
#        [0.32464498, 0.311384  ],
#        [0.5737055 , 0.243777  ],
#        [0.546009  , 0.09398705],
#        [0.40261057, 0.11757049],
#        [0.500663  , 0.21964675],
#        [0.29717314, 0.23125333],
#        [0.6739301 , 0.33410776],
#        [0.6253597 , 0.1488516 ],
#        [0.3597831 , 0.17735416],
#        [0.43355197, 0.23608458],
#        [0.392594  , 0.23541823],
#        [0.46132073, 0.15546286],
#        [0.53788257, 0.25857514],
#        [0.95174646, 0.04184607],
#        [0.28097135, 0.21117315],
#        [0.23196456, 0.16402388],
#        [0.5059654 , 0.17511863],
#        [0.7011267 , 0.16791722],
#        [0.6127724 , 0.09232625],
#        [0.6215438 , 0.13170367],
#        [0.7715229 , 0.16772467],
#        [0.5590918 , 0.22416022],
#        [0.5484159 , 0.26573274],
#        [0.3537202 , 0.3438587 ],
#        [0.7302261 , 0.17430383],
#        [0.6912735 , 0.11221588],
#        [0.5677036 , 0.0702953 ],
#        [0.45177498, 0.10944453],
#        [0.44210324, 0.12143415],
#        [0.35246992, 0.21289724],
#        [0.51141673, 0.11233306],
#        [0.5351201 , 0.18660843],
#        [0.5647305 , 0.23146567],
#        [0.60218114, 0.38109562],
#        [0.9398387 , 0.07315066],
#        [0.6521252 , 0.2647028 ],
#        [0.72605723, 0.08287156],
#        [0.52904123, 0.1633026 ],
#        [0.24342132, 0.22301978],
#        [0.83693147, 0.08186594],
#        [0.579554  , 0.0845089 ],
#        [0.628394  , 0.29546112],
#        [0.5076538 , 0.21480668],
#        [0.41036475, 0.12322   ],
#        [0.59235823, 0.0731189 ],
#        [0.39210325, 0.16037935],
#        [0.7159973 , 0.10688269],
#        [0.50419897, 0.12487456],
#        [0.25138006, 0.20023504],
#        [0.36338317, 0.13175309],
#        [0.6400902 , 0.20139158],
#        [0.3303883 , 0.22825676],
#        [0.33922735, 0.16992313],
#        [0.5762129 , 0.09999511],
#        [0.46666571, 0.1096786 ],
#        [0.57502246, 0.20904642],
#        [0.8521695 , 0.09860367],
#        [0.4685325 , 0.07036826],
#        [0.597537  , 0.09294087],
#        [0.39487207, 0.16345584],
#        [0.6949679 , 0.29482186],
#        [0.6732875 , 0.2609171 ],
#        [0.48414677, 0.21068123],
#        [0.42095932, 0.17875606],
#        [0.56686467, 0.23165813],
#        [0.4643845 , 0.23181996],
#        [0.39320827, 0.13010427],
#        [0.70134765, 0.19624501],
#        [0.31434345, 0.17813942],
#        [0.4952126 , 0.33693346],
#        [0.32738298, 0.1962555 ],
#        [0.6827528 , 0.06960505],
#        [0.43904832, 0.19113708],
#        [0.36997035, 0.16559726],
#        [0.48596722, 0.25180152],
#        [0.53561896, 0.23853624],
#        [0.25257498, 0.21539038],
#        [0.79581296, 0.13963088],
#        [0.51426804, 0.19938567],
#        [0.4998157 , 0.12242457],
#        [0.4092514 , 0.18729687],
#        [0.37481105, 0.09451449],
#        [0.49724463, 0.09514728],
#        [0.5839254 , 0.12508193],
#        [0.44025546, 0.17868435],
#        [0.5764058 , 0.30268723],
#        [0.32249153, 0.23552424],
#        [0.55671906, 0.24930912],
#        [0.47488183, 0.30095392],
#        [0.5340791 , 0.11248985],
#        [0.5753331 , 0.3167851 ],
#        [0.42189813, 0.23146716],
#        [0.328341  , 0.20803624],
#        [0.32220367, 0.18948379],
#        [0.46910152, 0.14011279],
#        [0.35012233, 0.17141786],
#        [0.4659199 , 0.19471222],
#        [0.36672747, 0.3441071 ],
#        [0.42529154, 0.17565003],
#        [0.48405564, 0.31133997],
#        [0.52393275, 0.08768567],
#        [0.617429  , 0.15911204],
#        [0.53470695, 0.21238422],
#        [0.8592576 , 0.32110882],
#        [0.52528125, 0.20150492],
#        [0.48165095, 0.22070879],
#        [0.43861994, 0.248709  ],
#        [0.67073077, 0.3549376 ],
#        [0.29296672, 0.12946606],
#        [0.6043335 , 0.32414407],
#        [0.44641286, 0.14173672],
#        [0.43133864, 0.18251583],
#        [0.27578184, 0.33355874],
#        [0.6577522 , 0.1940923 ],
#        [0.3440211 , 0.2280634 ],
#        [0.57729805, 0.13481441],
#        [0.5293728 , 0.32085672],
#        [0.4944205 , 0.17346397],
#        [0.48588085, 0.19020611],
#        [0.5692128 , 0.11145613],
#        [0.49848205, 0.20168036],
#        [0.6195052 , 0.09451926],
#        [0.6207626 , 0.09748203],
#        [0.50237566, 0.1884928 ],
#        [0.57430613, 0.31922862],
#        [0.80280304, 0.12060452],
#        [0.5597011 , 0.23502353],
#        [0.40640616, 0.34219736],
#        [0.4041872 , 0.1763621 ],
#        [0.5197574 , 0.2331416 ],
#        [0.3817455 , 0.34618652],
#        [0.37178457, 0.23318401],
#        [0.3470653 , 0.15120786]], dtype=float32)

# %%
validate_df['prediction'] = np.argmax(predict, axis=-1)
validate_df["prediction"] = validate_df["prediction"].replace({1: 'unmarked', 0: 'marked'}) 
validate_df
# Out:
#                       filename  category prediction
# 0        PaperedControl46v.tif    marked     marked
# 1        NoPaperedMixed38v.tif  unmarked     marked
# 2        NoPaperedGreen43v.tif  unmarked     marked
# 3         NoPaperedMixed7v.tif  unmarked     marked
# 4     PaperedTransparent9v.tif    marked     marked
# ..                         ...       ...        ...
# 147  PaperedTransparent99d.tif    marked     marked
# 148      NoPaperedGreen61v.tif  unmarked     marked
# 149      NoPaperedGreen57d.tif  unmarked     marked
# 150      PaperedControl65v.tif    marked     marked
# 151  PaperedTransparent76d.tif    marked     marked
#
# [152 rows x 3 columns]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_true=list(validate_df['category'])
y_pred=list(validate_df['prediction'])
cm=confusion_matrix(y_true, y_pred, labels=["marked", "unmarked"])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["marked", "unmarked"])
disp.plot(values_format="d")

# %%
cm
# Out:
# array([[96,  0],
#        [55,  1]])

# %%
validation_accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])

# %%
validation_accuracy
# Out:
# 0.6381578947368421
